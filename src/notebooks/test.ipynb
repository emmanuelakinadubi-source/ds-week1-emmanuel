# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\emman\Desktop\ds-1\data\titanic1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# EDA - Exploratory data analysis
# Data pre processing
#
# nulls, missing values: usually representated by NAN - imputation - inputation strateiges ( mean, median (numerical) - model (categorical) )strategies
# duplicates
# outliers
#
# Duplicate - drop
# outliers - Right, Wrong
#
# Outliers are unusual occourence, that are not possible

# %%
# Getting missing values
df.isna().sum()
# Out:
# Unnamed: 0       0
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# checking for duplicate
df.duplicated().sum()

# if there are duplicates, we use drop duplicate
# Out:
# np.int64(0)

# %%
# Data Skew

# %%
df.describe()
# Out:
#        Unnamed: 0  PassengerId    Survived      Pclass         Age  \
# count  891.000000   891.000000  891.000000  891.000000  714.000000
# mean   445.000000   446.000000    0.383838    2.308642   29.699118
# std    257.353842   257.353842    0.486592    0.836071   14.526497
# min      0.000000     1.000000    0.000000    1.000000    0.420000
# 25%    222.500000   223.500000    0.000000    2.000000   20.125000
# 50%    445.000000   446.000000    0.000000    3.000000   28.000000
# 75%    667.500000   668.500000    1.000000    3.000000   38.000000
# max    890.000000   891.000000    1.000000    3.000000   80.000000
#
#             SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208
# std      1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# ...

# %%
# df['Age'].fillna()

mean_age = df['Age'].mean()
print(mean_age)
# Out:
# 29.69911764705882

# %%
df['Age'].fillna(mean_age, inplace=True)
# Out:
# C:\Users\emman\AppData\Local\Temp\ipykernel_15300\3636672125.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(mean_age, inplace=True)

# %%
df['Age']
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df.describe()
# Out:
#        Unnamed: 0  PassengerId    Survived      Pclass         Age  \
# count  891.000000   891.000000  891.000000  891.000000  891.000000
# mean   445.000000   446.000000    0.383838    2.308642   29.699118
# std    257.353842   257.353842    0.486592    0.836071   13.002015
# min      0.000000     1.000000    0.000000    1.000000    0.420000
# 25%    222.500000   223.500000    0.000000    2.000000   22.000000
# 50%    445.000000   446.000000    0.000000    3.000000   29.699118
# 75%    667.500000   668.500000    1.000000    3.000000   35.000000
# max    890.000000   891.000000    1.000000    3.000000   80.000000
#
#             SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208
# std      1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# ...

# %%
df['Age'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Univariant

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.histplot(df['Age'], kde=True)
plt.title('Age Distribution')
plt.show()

# %%
# categorical variables

for c in ['Sex', 'Pclass', 'Embarked']:
    plt.figure()
    sns.countplot(x=c, data=df, order=df [c].value_counts().index)
    plt.title(f'{c} Distribution')
    plt.show()

# %%
# Bivariate Analysis

# %%
target = 'Survived'
df[target].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.barplot(x=target, y='Age', data=df)
plt.title('Age vs Survived')
plt.show()

# %%
sns.boxplot(x=target, y='Age', data=df)
plt.title('Age vs Survived')
plt.show()

# %% [markdown]
# Whisckers
# Outliers

# %% [markdown]
# Blue 25%
# Middle line (Median) - 50%
# top line 75%
#
# formular (75% - 25%) * 1.5
#
# (q3-q1) * 1.5

# %%
# Multivariate Analysis

sns.catplot(x=target, y='Age', hue='Pclass', kind='bar', data=df)
plt.title('Age vs Survived by Passenger Class')
plt.show()

# %%
# df['Unnamed: 0'].nunique()
# 

# df.drop(['Unnamed:0', 'PassengerId'], axis=1, inplace=True)

# %%
import numpy as np
num = df.select_dtypes(include= np.number)
corr = num.corr(numeric_only=True)

plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap='cividis')
plt.title('Correlation heatmap')
plt.show()

# %% [markdown]
# positive corr > -1
# neutral > 0
#
# Corrolation is not causuation
# Feature engineering
# Feature causuation.
